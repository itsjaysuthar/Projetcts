# %%
import numpy as np
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("country_vaccinations.csv")
data.head()
# Out:
#        country iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG  2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG  2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG  2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG  2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG  2021-02-26                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN              1367.0
# 2                      NaN                     NaN              1367.0
# 3                      NaN                     NaN              1367.0
# 4                      NaN                     NaN              1367.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                             0.0                            0.0
# 1                             NaN                            NaN
# 2                             NaN                            NaN
# 3                             NaN                            NaN
# 4                             NaN                            NaN
#
#    people_fully_vaccinated_per_hundred  daily_vaccinations_per_million  \
# 0                                  NaN                             NaN
# 1                                  NaN                            35.0
# 2                                  NaN                            35.0
# 3                                  NaN                            35.0
# 4                                  NaN                            35.0
#
#              vaccines                source_name  \
# 0  Oxford/AstraZeneca  Government of Afghanistan
# 1  Oxford/AstraZeneca  Government of Afghanistan
# 2  Oxford/AstraZeneca  Government of Afghanistan
# 3  Oxford/AstraZeneca  Government of Afghanistan
# 4  Oxford/AstraZeneca  Government of Afghanistan
#
#                                       source_website
# 0  https://reliefweb.int/report/afghanistan/afgha...
# 1  https://reliefweb.int/report/afghanistan/afgha...
# 2  https://reliefweb.int/report/afghanistan/afgha...
# 3  https://reliefweb.int/report/afghanistan/afgha...
# 4  https://reliefweb.int/report/afghanistan/afgha...

# %%
data.shape
# Out:
# (15666, 15)

# %%
data.country.value_counts()
# Out:
# Canada           144
# China            143
# Russia           143
# Israel           139
# United States    138
#                 ...
# Congo              1
# Timor              1
# Comoros            1
# Somalia            1
# Libya              1
# Name: country, Length: 196, dtype: int64

# %%
data = data[data.country.apply(lambda x: x not in ["England", "Scotland", "Wales", "Northern Ireland"])]
data.country.value_counts()
# Out:
# Canada           144
# Russia           143
# China            143
# Israel           139
# United States    138
#                 ...
# Libya              1
# Djibouti           1
# Armenia            1
# Comoros            1
# Congo              1
# Name: country, Length: 192, dtype: int64

# %%
data.vaccines.value_counts()
# Out:
# Oxford/AstraZeneca                                                                    2607
# Moderna, Oxford/AstraZeneca, Pfizer/BioNTech                                          1897
# Johnson&Johnson, Moderna, Oxford/AstraZeneca, Pfizer/BioNTech                         1532
# Oxford/AstraZeneca, Pfizer/BioNTech                                                   1418
# Pfizer/BioNTech                                                                       1227
# Moderna, Pfizer/BioNTech                                                               604
# Oxford/AstraZeneca, Sinopharm/Beijing                                                  587
# Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac                                           499
# Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sputnik V                      487
# Oxford/AstraZeneca, Sinovac                                                            472
# Sputnik V                                                                              438
# Pfizer/BioNTech, Sinovac                                                               391
# Oxford/AstraZeneca, Sinopharm/Beijing, Sputnik V                                       311
# Sinopharm/Beijing                                                                      310
# Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing                                 242
# Pfizer/BioNTech, Sinopharm/Beijing                                                     201
# Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac, Sputnik V                                193
# Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac                                         167
# EpiVacCorona, Sputnik V                                                                143
# Sinopharm/Beijing, Sinopharm/Wuhan, Sinovac                                            143
# Johnson&Johnson, Moderna, Pfizer/BioNTech                                              138
# CanSino, Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac, Sputnik V                       133
# Moderna, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sputnik V             129
# Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sinopharm/Wuhan, Sputnik V     122
# Covaxin, Oxford/AstraZeneca                                                            112
# Moderna, Oxford/AstraZeneca                                                            111
# Oxford/AstraZeneca, Sputnik V                                                          111
# CanSino, Sinopharm/Beijing, Sinovac, Sputnik V                                          93
# Oxford/AstraZeneca, Pfizer/BioNTech, Sputnik V                                          79
# Johnson&Johnson                                                                         79
# Sinopharm/Beijing, Sputnik V                                                            74
# Pfizer/BioNTech, Sputnik V                                                              68
# Pfizer/BioNTech, Sinovac, Sputnik V                                                     55
# Oxford/AstraZeneca, Sinovac, Sputnik V                                                   1
# Name: vaccines, dtype: int64

# %%
df = data[["vaccines", "country"]]
df.head()
# Out:
#              vaccines      country
# 0  Oxford/AstraZeneca  Afghanistan
# 1  Oxford/AstraZeneca  Afghanistan
# 2  Oxford/AstraZeneca  Afghanistan
# 3  Oxford/AstraZeneca  Afghanistan
# 4  Oxford/AstraZeneca  Afghanistan

# %%
dict_ = {}
for i in df.vaccines.unique():
  dict_[i] = [df["country"][j] for j in df[df["vaccines"]==i].index]

vaccines = {}
for key, value in dict_.items():
  vaccines[key] = set(value)
for i, j in vaccines.items():
  print(f"{i}:>>{j}")
# Out:
# Oxford/AstraZeneca:>>{'Taiwan', 'Trinidad and Tobago', 'Anguilla', 'Uzbekistan', 'Nauru', 'Jamaica', 'Democratic Republic of Congo', 'Belize', 'Ethiopia', 'Cape Verde', 'Mauritius', 'Papua New Guinea', 'Angola', 'Saint Vincent and the Grenadines', 'Sierra Leone', 'Nigeria', 'Fiji', 'Ghana', 'Saint Helena', 'Saint Kitts and Nevis', 'Suriname', 'Samoa', 'Tonga', 'Zambia', 'Bahamas', 'Mali', 'Uganda', 'Kosovo', 'Bangladesh', 'Bhutan', 'Botswana', 'Brunei', 'Guyana', 'Sao Tome and Principe', 'Malawi', 'Barbados', "Cote d'Ivoire", 'Georgia', 'Antigua and Barbuda', 'Montserrat', 'Saint Lucia', 'South Sudan', 'Gambia', 'Dominica', 'Togo', 'Timor', 'Djibouti', 'Myanmar', 'Solomon Islands', 'Comoros', 'Falkland Islands', 'Eswatini', 'Vietnam', 'Lesotho', 'Grenada', 'Afghanistan', 'Sudan'}
# Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac, Sputnik V:>>{'Bosnia and Herzegovina', 'Albania'}
# Sputnik V:>>{'Paraguay', 'Venezuela', 'Kazakhstan', 'Belarus', 'Guinea', 'Armenia', 'Algeria', 'Syria'}
# Oxford/AstraZeneca, Pfizer/BioNTech:>>{'Andorra', 'Sweden', 'Panama', 'Australia', 'Guernsey', 'Cayman Islands', 'Saudi Arabia', 'Jersey', 'Slovenia', 'Costa Rica', 'Isle of Man', 'South Korea', 'Oman'}
# Oxford/AstraZeneca, Sinopharm/Beijing, Sputnik V:>>{'Argentina', 'Bolivia', 'Iran'}
# Pfizer/BioNTech:>>{'Bermuda', 'Turks and Caicos Islands', 'Qatar', 'Cyprus', 'New Zealand', 'Slovakia', 'Kuwait', 'Greenland', 'Monaco', 'Aruba', 'Japan', 'Gibraltar'}
# Johnson&Johnson, Moderna, Oxford/AstraZeneca, Pfizer/BioNTech:>>{'Spain', 'Latvia', 'Belgium', 'Italy', 'Lithuania', 'Germany', 'Netherlands', 'France', 'Poland', 'Czechia', 'Romania', 'Austria'}
# Oxford/AstraZeneca, Sinovac:>>{'Philippines', 'Indonesia', 'Azerbaijan', 'Thailand', 'Brazil'}
# Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sputnik V:>>{'Lebanon', 'Mongolia', 'Montenegro', 'Serbia', 'Bahrain'}
# Moderna, Oxford/AstraZeneca, Pfizer/BioNTech:>>{'Norway', 'Ireland', 'Croatia', 'Finland', 'Iceland', 'Portugal', 'Greece', 'Bulgaria', 'Luxembourg', 'Denmark', 'Palestine', 'Rwanda', 'Malta', 'Estonia', 'Canada', 'United Kingdom'}
# Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac:>>{'Cambodia', 'Dominican Republic'}
# Sinopharm/Beijing:>>{'Senegal', 'Gabon', 'Cameroon', 'Niger', 'Mozambique', 'Equatorial Guinea', 'Mauritania', 'Zimbabwe'}
# Pfizer/BioNTech, Sinovac:>>{'Turkey', 'Hong Kong', 'Malaysia', 'Chile'}
# Sinopharm/Beijing, Sinopharm/Wuhan, Sinovac:>>{'China'}
# Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac:>>{'El Salvador', 'Uruguay', 'Ecuador', 'Colombia', 'Northern Cyprus', 'Ukraine'}
# Sinopharm/Beijing, Sputnik V:>>{'Laos', 'Kyrgyzstan', 'Congo'}
# Moderna, Pfizer/BioNTech:>>{'Switzerland', 'Curacao', 'Singapore', 'Israel', 'Liechtenstein', 'Faeroe Islands'}
# Oxford/AstraZeneca, Sinopharm/Beijing:>>{'Morocco', 'Iraq', 'Nepal', 'Somalia', 'Sri Lanka', 'Seychelles', 'Egypt', 'Namibia'}
# Moderna, Oxford/AstraZeneca:>>{'Guatemala', 'Honduras'}
# Moderna, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sputnik V:>>{'Hungary'}
# Covaxin, Oxford/AstraZeneca:>>{'India'}
# Pfizer/BioNTech, Sinopharm/Beijing:>>{'Jordan', 'Macao'}
# Oxford/AstraZeneca, Sputnik V:>>{'Nicaragua', 'Kenya'}
# Oxford/AstraZeneca, Sinovac, Sputnik V:>>{'Libya'}
# Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing:>>{'Moldova', 'Maldives', 'Peru'}
# CanSino, Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac, Sputnik V:>>{'Mexico'}
# Oxford/AstraZeneca, Pfizer/BioNTech, Sputnik V:>>{'North Macedonia'}
# CanSino, Sinopharm/Beijing, Sinovac, Sputnik V:>>{'Pakistan'}
# EpiVacCorona, Sputnik V:>>{'Russia'}
# Pfizer/BioNTech, Sputnik V:>>{'San Marino'}
# Johnson&Johnson:>>{'South Africa'}
# Pfizer/BioNTech, Sinovac, Sputnik V:>>{'Tunisia'}
# Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sinopharm/Wuhan, Sputnik V:>>{'United Arab Emirates'}
# Johnson&Johnson, Moderna, Pfizer/BioNTech:>>{'United States'}

# %%
import plotly.express as px
import plotly.offline as py

vaccine_map = px.choropleth(data, locations = 'iso_code', color = 'vaccines')
vaccine_map.update_layout(height=300, margin={"r":0,"t":0,"l":0,"b":0})
vaccine_map.show()
# Out:
# <div>                            <div id="19c6b7ab-0f63-453d-b87f-d7242ee2d42e" class="plotly-graph-div" style="height:300px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("19c6b7ab-0f63-453d-b87f-d7242ee2d42e")) {                    Plotly.newPlot(                        "19c6b7ab-0f63-453d-b87f-d7242ee2d42e",                        [{"colorscale": [[0.0, "#636efa"], [1.0, "#636efa"]], "geo": "geo", "hovertemplate": "vaccines=Oxford/AstraZeneca<br>iso_code=%{location}<extra></extra>", "locations": ["AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "ATG", "ATG", "ATG", "ATG", "ATG", "ATG", "ATG", "ATG", "ATG", "ATG", "ATG", "ATG", "ATG", "ATG", "ATG", "ATG", "ATG", "ATG", "ATG", "ATG", "ATG", "ATG", "ATG", "ATG", "ATG", "ATG", "ATG", "ATG", "ATG", "ATG", "ATG", "ATG", "ATG", "ATG", "ATG", "ATG", "ATG", "ATG", "ATG", "ATG", "ATG", "ATG", "ATG", "ATG", "ATG", "ATG", "ATG", "ATG", "ATG", "ATG", "ATG", "ATG", "ATG", "ATG", "ATG", "ATG", "ATG", "ATG", "ATG", "ATG", "ATG", "ATG", "ATG", "ATG", "ATG", "ATG", "BHS", "BHS", "BHS", "BHS", "BHS", "BHS", "BHS", "BHS", "BHS", "BHS", "BHS", "BHS", "BHS", "BHS", "BHS", "BHS", "BHS", "BHS", "BHS", "BHS", "BHS", "BHS", "BHS", "BHS", "BHS", "BHS", "BHS", "BHS", "BHS", "BHS", "BHS", "BHS", "BHS", "BHS", "BHS", "BHS", "BHS", "BHS", "BHS", "BHS", "BHS", "BHS", "BHS", "BHS", "BHS", "BHS", "BGD", "BGD", "BGD", "BGD", "BGD", "BGD", "BGD", "BGD", "BGD", "BGD", "BGD", "BGD", "BGD", "BGD", "BGD", "BGD", "BGD", "BGD", "BGD", "BGD", "BGD", "BGD", "BGD", "BGD", "BGD", "BGD", "BGD", "BGD", "BGD", "BGD", "BGD", "BGD", "BGD", "BGD", "BGD", "BGD", "BGD", "BGD", "BGD", "BGD", "BGD", "BGD", "BGD", "BGD", "BGD", "BGD", "BGD", "BGD", "BGD", "BGD", "BGD", "BGD", "BGD", "BGD", "BGD", "BGD", "BGD", "BGD", "BGD", "BGD", "BGD", "BGD", "BGD", "BGD", "BGD", "BGD", "BGD", "BGD", "BGD", "BGD", "BGD", "BGD", "BGD", "BGD", "BGD", "BGD", "BGD", "BGD", "BGD", "BGD", "BGD", "BGD", "BGD", "BGD", "BGD", "BGD", "BGD", "BGD", "BGD", "BGD", "BGD", "BGD", "BGD", "BGD", "BGD", "BGD", "BGD", "BGD", "BGD", "BGD", "BGD", "BRB", "BRB", "BRB", "BRB", "BRB", "BRB", "BRB", "BRB", "BRB", "BRB", "BRB", "BRB", "BRB", "BRB", "BRB", "BRB", "BRB", "BRB", "BRB", "BRB", "BRB", "BRB", "BRB", "BRB", "BRB", "BRB", "BRB", "BRB", "BRB", "BRB", "BRB", "BRB", "BRB", "BRB", "BRB", "BRB", "BRB", "BRB", "BRB", "BRB", "BRB", "BRB", "BRB", "BRB", "BRB", "BRB", "BRB", "BRB", "BRB", "BRB", "BRB", "BRB", "BRB", "BRB", "BRB", "BRB", "BRB", "BRB", "BRB", "BRB", "BRB", "BRB", "BRB", "BRB", "BRB", "BRB", "BRB ...
